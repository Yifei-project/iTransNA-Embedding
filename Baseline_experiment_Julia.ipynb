# %%
using DynamicalSystems
using DelayEmbeddings
using HDF5

# %% [markdown]
# # PECUZAL

# %%
# univariate reconstruction
for i = 1:100
    fid = h5open("./data/3D-lorenz/lorenz_no"*string(i)*".h5", "r")
    # fid = h5open("./data/Rossler/rossler_no"*string(i)*".h5", "r")
    # fid = h5open("./data/Lorenz96/lorenz96_N8_no"*string(i)*".h5", "r")
    Y = fid["xM"]

    s = vec(Y[:, 2]) # input timeseries = y-component of Lorenz
    theiler = estimate_delay(s, "mi_min") # estimate a Theiler window
    Tmax = 50 # maximum possible delay
    close(fid)

    Recon_pec, τ_vals, ts_vals, Ls, εs = pecuzal_embedding(s; τs = 0:Tmax , w = theiler, L_threshold=0, econ = true)
    println(τ_vals, ts_vals)
    ff = h5open("./results/PECUZAL/3D-lorenz/lorenz_uni_no"*string(i)*".h5", "w")
    ff["Embedding"] = Matrix(Recon_pec)
    ff["delays"] = τ_vals
    close(ff)
    
end

for i = 1:100
    # fid = h5open("./data/3D-lorenz/lorenz_no"*string(i)*".h5", "r")
    fid = h5open("./data/Rossler/rossler_no"*string(i)*".h5", "r")
    # fid = h5open("./data/Lorenz96/lorenz96_N8_no"*string(i)*".h5", "r")
    Y = fid["xM"]

    s = vec(Y[:, 2]) # input timeseries = y-component of Rossler
    theiler = estimate_delay(s, "mi_min") # estimate a Theiler window
    Tmax = 50 # maximum possible delay
    close(fid)

    Recon_pec, τ_vals, ts_vals, Ls, εs = pecuzal_embedding(s; τs = 0:Tmax , w = theiler, L_threshold=0, econ = true)
    println(τ_vals, ts_vals)
    ff = h5open("./results/PECUZAL/Rossler/rossler_uni_no"*string(i)*".h5", "w")
    ff["Embedding"] = Matrix(Recon_pec)
    ff["delays"] = τ_vals
    close(ff)
    
end

for i = 1:100
    # fid = h5open("./data/3D-lorenz/lorenz_no"*string(i)*".h5", "r")
    # fid = h5open("./data/Rossler/rossler_no"*string(i)*".h5", "r")
    fid = h5open("./data/Lorenz96/lorenz96_N8_no"*string(i)*".h5", "r")
    Y = fid["xM"]

    s = vec(Y[:, 2]) # input timeseries = x2-component of Lorenz96
    theiler = estimate_delay(s, "mi_min") # estimate a Theiler window
    Tmax = 50 # maximum possible delay
    close(fid)

    Recon_pec, τ_vals, ts_vals, Ls, εs = pecuzal_embedding(s; τs = 0:Tmax , w = theiler, L_threshold=0, econ = true)
    println(τ_vals, ts_vals)
    ff = h5open("./results/PECUZAL/Lorenz96/lorenz96_uni_no"*string(i)*".h5", "w")
    ff["Embedding"] = Matrix(Recon_pec)
    ff["delays"] = τ_vals
    close(ff)
    
end

# %%
# mutlivariate reconstruction
for i = 1:100
    fid = h5open("./data/3D-lorenz/lorenz_no"*string(i)*".h5", "r")
    # fid = h5open("./data/Rossler/rossler_no"*string(i)*".h5", "r")
    # fid = h5open("./data/Lorenz96/lorenz96_N8_no"*string(i)*".h5", "r")
    Y = Array(fid["xM"])

    inds = [2,3] # input timeseries = y-component and z-component of Lorenz
    theiler1 = estimate_delay(Y[:,2], "mi_min") # estimate a Theiler window
    theiler2 = estimate_delay(Y[:,3], "mi_min")
    theiler = maximum(hcat(theiler1, theiler2))
    Tmax = 50 # maximum possible delay

    Recon_pec, τ_vals, ts_vals, Ls, εs = pecuzal_embedding(Dataset(Y[:,inds]); τs = 0:Tmax , w = theiler, L_threshold=0, econ = true)
    println(τ_vals, ts_vals)
    ff = h5open("./PECUZAL/3D-lorenz/lorenz_multi_no"*string(i)*".h5", "w")
    ff["Embedding"] = Matrix(Recon_pec)
    ff["delays"] = τ_vals
    close(ff)
    close(fid)
end

for i = 1:100
    # fid = h5open("./data/3D-lorenz/lorenz_no"*string(i)*".h5", "r")
    fid = h5open("./data/Rossler/rossler_no"*string(i)*".h5", "r")
    # fid = h5open("./data/Lorenz96/lorenz96_N8_no"*string(i)*".h5", "r")
    Y = Array(fid["xM"])

    inds = [1,2] # input timeseries = x-component and y-component of Rossler
    theiler1 = estimate_delay(Y[:,1], "mi_min") # estimate a Theiler window
    theiler2 = estimate_delay(Y[:,2], "mi_min")
    theiler = maximum(hcat(theiler1, theiler2))
    Tmax = 50 # maximum possible delay

    Recon_pec, τ_vals, ts_vals, Ls, εs = pecuzal_embedding(Dataset(Y[:,inds]); τs = 0:Tmax , w = theiler, L_threshold=0, econ = true)
    println(τ_vals, ts_vals)
    ff = h5open("./PECUZAL/Rossler/rossler_multi_no"*string(i)*".h5", "w")
    ff["Embedding"] = Matrix(Recon_pec)
    ff["delays"] = τ_vals
    close(ff)
    close(fid)
end

for i = 1:100
    # fid = h5open("./data/3D-lorenz/lorenz_no"*string(i)*".h5", "r")
    # fid = h5open("./data/Rossler/rossler_no"*string(i)*".h5", "r")
    fid = h5open("./data/Lorenz96/lorenz96_N8_no"*string(i)*".h5", "r")
    Y = Array(fid["xM"])

    inds = [2,6] # input timeseries = x2-component and x6-component of Lorenz96
    theiler1 = estimate_delay(Y[:,2], "mi_min") # estimate a Theiler window
    theiler2 = estimate_delay(Y[:,6], "mi_min")
    theiler = maximum(hcat(theiler1, theiler2))
    Tmax = 50 # maximum possible delay

    Recon_pec, τ_vals, ts_vals, Ls, εs = pecuzal_embedding(Dataset(Y[:,inds]); τs = 0:Tmax , w = theiler, L_threshold=0, econ = true)
    println(τ_vals, ts_vals)
    ff = h5open("./PECUZAL/Lorenz96/lorenz96_multi_no"*string(i)*".h5", "w")
    ff["Embedding"] = Matrix(Recon_pec)
    ff["delays"] = τ_vals
    close(ff)
    close(fid)
end

# %% [markdown]
# # MDOP

# %%
# univariate reconstruction
for i = 1:100
    fid = h5open("./data/3D-lorenz/lorenz_no"*string(i)*".h5", "r")
    # fid = h5open("./data/Rossler/rossler_no"*string(i)*".h5", "r")
    # fid = h5open("./data/Lorenz96/lorenz96_N8_no"*string(i)*".h5", "r")
    Y = fid["xM"]

    s = vec(Y[:, 2]) # input timeseries = y-component of Lorenz
    w = estimate_delay(s, "mi_min") #
    tw = mdop_maximum_delay(s, 50) #
    lm = findlocalminima(tw[2])
    # println(lm)
    if lm[1] ≤ 2
        lmm = try lm[2]
        catch
            lm[1]
        end
    else
        lmm = lm[1]
    end
    taus_mdop = 0:lmm
    # taus_mdop = 1:50
    close(fid)

    Recon_mdop, τ_vals_mdop, ts_vals_mdop, FNNs_mdop , βs_mdop = mdop_embedding(s; τs = taus_mdop , w = w)
    println(τ_vals_mdop, ts_vals_mdop)
    ff = h5open("./results/MDOP/3D-lorenz/lorenz_uni_no"*string(i)*".h5", "w")
    ff["Embedding"] = Matrix(Recon_mdop)
    ff["delays"] = τ_vals_mdop
    close(ff)

for i = 1:100
    # fid = h5open("./data/3D-lorenz/lorenz_no"*string(i)*".h5", "r")
    fid = h5open("./data/Rossler/rossler_no"*string(i)*".h5", "r")
    # fid = h5open("./data/Lorenz96/lorenz96_N8_no"*string(i)*".h5", "r")
    Y = fid["xM"]

    s = vec(Y[:, 2]) # input timeseries = y-component of Rossler
    w = estimate_delay(s, "mi_min") #
    # tw = mdop_maximum_delay(s, 50) #
    # # applying L-statistic to determine the maximal delay
    # lm = findlocalminima(tw[2])
    # # println(lm)
    # if lm[1] ≤ 2
    #     lmm = try lm[2]
    #     catch
    #         lm[1]
    #     end
    # else
    #     lmm = lm[1]
    # end
    # taus_mdop = 0:lmm
    taus_mdop = 1:50
    # println(lm)
    close(fid)

    Recon_mdop, τ_vals_mdop, ts_vals_mdop, FNNs_mdop , βs_mdop = mdop_embedding(s; τs = taus_mdop , w = w)
    println(τ_vals_mdop, ts_vals_mdop)
    ff = h5open("./results/MDOP/Rossler/rossler_uni_no"*string(i)*".h5", "w")
    ff["Embedding"] = Matrix(Recon_mdop)
    ff["delays"] = τ_vals_mdop
    close(ff)
    
end

for i = 1:100
    # fid = h5open("./data/3D-lorenz/lorenz_no"*string(i)*".h5", "r")
    # fid = h5open("./data/Rossler/rossler_no"*string(i)*".h5", "r")
    fid = h5open("./data/Lorenz96/lorenz96_N8_no"*string(i)*".h5", "r")
    Y = fid["xM"]

    s = vec(Y[:, 2]) # input timeseries = x2-component of Lorenz96
    w = estimate_delay(s, "mi_min") #
    # tw = mdop_maximum_delay(s, 50) #
    # # applying L-statistic to determine the maximal delay
    # lm = findlocalminima(tw[2])
    # # println(lm)
    # if lm[1] ≤ 2
    #     lmm = try lm[2]
    #     catch
    #         lm[1]
    #     end
    # else
    #     lmm = lm[1]
    # end
    # taus_mdop = 0:lmm
    taus_mdop = 1:50
    # println(lm)
    close(fid)

    Recon_mdop, τ_vals_mdop, ts_vals_mdop, FNNs_mdop , βs_mdop = mdop_embedding(s; τs = taus_mdop , w = w)
    println(τ_vals_mdop, ts_vals_mdop)
    ff = h5open("./results/MDOP/Lorenz96/lorenz96_uni_no"*string(i)*".h5", "w")
    ff["Embedding"] = Matrix(Recon_mdop)
    ff["delays"] = τ_vals_mdop
    close(ff)
    
end

# %%
# multivariate reconstruction
for i = 1:100
    fid = h5open("./data/3D-lorenz/lorenz_no"*string(i)*".h5", "r")
    # fid = h5open("./data/Rossler/rossler_no"*string(i)*".h5", "r")
    # fid = h5open("./data/Lorenz96/lorenz96_N8_no"*string(i)*".h5", "r")
    Y = Array(fid["xM"])

    inds = [2,3]  # input timeseries = y-component and z-component of Lorenz
    theiler1 = estimate_delay(Y[:,inds[1]], "mi_min") # estimate a Theiler window
    theiler2 = estimate_delay(Y[:,inds[2]], "mi_min")
    w = maximum(hcat(theiler1, theiler2))

    # applying L-statistic to determine the maximal delay
    tw1 = mdop_maximum_delay(Y[:,inds[1]]) #
    tw2 = mdop_maximum_delay(Y[:,inds[2]]) #
    lm1 = findlocalminima(tw1[2])
    lm2 = findlocalminima(tw2[2])
    # println(lm)
    if lm1[1] ≤ 2
        lmm1 = try lm1[2]
        catch
            lm1[1]
        end
    else
        lmm1 = lm1[1]
    end
    if lm2[1] ≤ 2
        lmm2 = try lm2[2]
        catch
            lm2[1]
        end
    else
        lmm2 = lm2[1]
    end
    lmm = maximum(hcat(lmm1, lmm2))
    taus_mdop = 0:lmm
    # taus_mdop = 1:50
    # println(lm)
    close(fid)

    Recon_mdop, τ_vals_mdop, ts_vals_mdop, FNNs_mdop , βs_mdop = mdop_embedding(Dataset(Y[:,inds]); τs = taus_mdop , w = w)
    println(τ_vals_mdop, ts_vals_mdop)
    ff = h5open("./results/MDOP/3D-lorenz-multi/lorenz_multi_no"*string(i)*".h5", "w")
    ff["Embedding"] = Matrix(Recon_mdop)
    ff["delays"] = τ_vals_mdop
    close(ff)
    
end


for i = 1:100
    # fid = h5open("./data/3D-lorenz/lorenz_no"*string(i)*".h5", "r")
    fid = h5open("./data/Rossler/rossler_no"*string(i)*".h5", "r")
    # fid = h5open("./data/Lorenz96/lorenz96_N8_no"*string(i)*".h5", "r")
    Y = Array(fid["xM"])

    inds = [1,2]  # input timeseries = x-component and y-component of Rossler
    theiler1 = estimate_delay(Y[:,inds[1]], "mi_min") # estimate a Theiler window
    theiler2 = estimate_delay(Y[:,inds[2]], "mi_min")
    w = maximum(hcat(theiler1, theiler2))

    # applying L-statistic to determine the maximal delay
    tw1 = mdop_maximum_delay(Y[:,inds[1]]) #
    tw2 = mdop_maximum_delay(Y[:,inds[2]]) #
    lm1 = findlocalminima(tw1[2])
    lm2 = findlocalminima(tw2[2])
    # println(lm)
    if lm1[1] ≤ 2
        lmm1 = try lm1[2]
        catch
            lm1[1]
        end
    else
        lmm1 = lm1[1]
    end
    if lm2[1] ≤ 2
        lmm2 = try lm2[2]
        catch
            lm2[1]
        end
    else
        lmm2 = lm2[1]
    end
    lmm = maximum(hcat(lmm1, lmm2))
    taus_mdop = 0:lmm
    # taus_mdop = 1:50
    # println(lm)
    close(fid)

    Recon_mdop, τ_vals_mdop, ts_vals_mdop, FNNs_mdop , βs_mdop = mdop_embedding(Dataset(Y[:,inds]); τs = taus_mdop , w = w)
    println(τ_vals_mdop, ts_vals_mdop)
    ff = h5open("./results/MDOP/Rossler-multi/rossler_multi_no"*string(i)*".h5", "w")
    ff["Embedding"] = Matrix(Recon_mdop)
    ff["delays"] = τ_vals_mdop
    close(ff)
    
end

for i = 1:100
    # fid = h5open("./data/3D-lorenz/lorenz_no"*string(i)*".h5", "r")
    # fid = h5open("./data/Rossler/rossler_no"*string(i)*".h5", "r")
    fid = h5open("./data/Lorenz96/lorenz96_N8_no"*string(i)*".h5", "r")
    Y = Array(fid["xM"])

    inds = [2,6]  # input timeseries = x2-component and x6-component of Lorenz96
    theiler1 = estimate_delay(Y[:,inds[1]], "mi_min") # estimate a Theiler window
    theiler2 = estimate_delay(Y[:,inds[2]], "mi_min")
    w = maximum(hcat(theiler1, theiler2))

    # applying L-statistic to determine the maximal delay
    tw1 = mdop_maximum_delay(Y[:,inds[1]]) #
    tw2 = mdop_maximum_delay(Y[:,inds[2]]) #
    lm1 = findlocalminima(tw1[2])
    lm2 = findlocalminima(tw2[2])
    # println(lm)
    if lm1[1] ≤ 2
        lmm1 = try lm1[2]
        catch
            lm1[1]
        end
    else
        lmm1 = lm1[1]
    end
    if lm2[1] ≤ 2
        lmm2 = try lm2[2]
        catch
            lm2[1]
        end
    else
        lmm2 = lm2[1]
    end
    lmm = maximum(hcat(lmm1, lmm2))
    taus_mdop = 0:lmm
    # taus_mdop = 1:50
    # println(lm)
    close(fid)

    Recon_mdop, τ_vals_mdop, ts_vals_mdop, FNNs_mdop , βs_mdop = mdop_embedding(Dataset(Y[:,inds]); τs = taus_mdop , w = w)
    println(τ_vals_mdop, ts_vals_mdop)
    ff = h5open("./results/MDOP/Lorenz96-multi/lorenz96_multi_no"*string(i)*".h5", "w")
    ff["Embedding"] = Matrix(Recon_mdop)
    ff["delays"] = τ_vals_mdop
    close(ff)
    
end

# %% [markdown]
# # G & A

# %%
# univariate reconstruction
for i = 1:100
    fid = h5open("./data/3D-lorenz/lorenz_no"*string(i)*".h5", "r")
    # fid = h5open("./data/Rossler/rossler_no"*string(i)*".h5", "r")
    # fid = h5open("./data/Lorenz96/lorenz96_N8_no"*string(i)*".h5", "r")
    Y = fid["xM"]

    s = vec(Y[:, 2]) # input timeseries = y-component of Lorenz
    theiler = estimate_delay(s, "mi_min") # estimate a Theiler window
    Tmax = 50 # maximum possible delay
    close(fid)

    Recon_GA, τ_vals_GA, ts_vals_GA, FNNs_GA , ns_GA = garcia_almeida_embedding(s; τs = 0:Tmax , w = theiler, T = theiler)
    println(τ_vals_GA, ts_vals_GA)
    ff = h5open("./results/GA/3D-lorenz/lorenz_uni_no"*string(i)*".h5", "w")
    ff["Embedding"] = Matrix(Recon_GA)
    ff["delays"] = τ_vals_GA
    close(ff)
    
end


for i = 1:100
    # fid = h5open("./data/3D-lorenz/lorenz_no"*string(i)*".h5", "r")
    fid = h5open("./data/Rossler/rossler_no"*string(i)*".h5", "r")
    # fid = h5open("./data/Lorenz96/lorenz96_N8_no"*string(i)*".h5", "r")
    Y = fid["xM"]

    s = vec(Y[:, 2]) # input timeseries = y-component of Rossler
    theiler = estimate_delay(s, "mi_min") # estimate a Theiler window
    Tmax = 50 # maximum possible delay
    close(fid)

    Recon_GA, τ_vals_GA, ts_vals_GA, FNNs_GA , ns_GA = garcia_almeida_embedding(s; τs = 0:Tmax , w = theiler, T = theiler)
    println(τ_vals_GA, ts_vals_GA)
    ff = h5open("./results/GA/Rossler/rossler_uni_no"*string(i)*".h5", "w")
    ff["Embedding"] = Matrix(Recon_GA)
    ff["delays"] = τ_vals_GA
    close(ff)
    
end


for i = 1:100
    # fid = h5open("./data/3D-lorenz/lorenz_no"*string(i)*".h5", "r")
    # fid = h5open("./data/Rossler/rossler_no"*string(i)*".h5", "r")
    fid = h5open("./data/Lorenz96/lorenz96_N8_no"*string(i)*".h5", "r")
    Y = fid["xM"]

    s = vec(Y[:, 2]) # input timeseries = x2-component of Lorenz96
    theiler = estimate_delay(s, "mi_min") # estimate a Theiler window
    Tmax = 50 # maximum possible delay
    close(fid)

    Recon_GA, τ_vals_GA, ts_vals_GA, FNNs_GA , ns_GA = garcia_almeida_embedding(s; τs = 0:Tmax , w = theiler, T = theiler)
    println(τ_vals_GA, ts_vals_GA)
    ff = h5open("./results/GA/Lorenz96/lorenz96_uni_no"*string(i)*".h5", "w")
    ff["Embedding"] = Matrix(Recon_GA)
    ff["delays"] = τ_vals_GA
    close(ff)
    
end

# %%
# multivariate reconstruction
for i = 1:100
    fid = h5open("./data/3D-lorenz/lorenz_no"*string(i)*".h5", "r")
    # fid = h5open("./data/Rossler/rossler_no"*string(i)*".h5", "r")
    # fid = h5open("./data/Lorenz96/lorenz96_N8_no"*string(i)*".h5", "r")
    Y = Array(fid["xM"])

    inds = [2,3] # input timeseries = y-component and z-component of Lorenz
    theiler1 = estimate_delay(Y[:,inds[1]], "mi_min") # estimate a Theiler window
    theiler2 = estimate_delay(Y[:,inds[2]], "mi_min")
    w = maximum(hcat(theiler1, theiler2))
    Tmax = 50 # maximum possible delay


    Recon_GA, τ_vals_GA, ts_vals_GA, FNNs_GA , ns_GA = garcia_almeida_embedding(Dataset(Y[:,inds]); τs = 0:Tmax , w = w, T = w)
    println(τ_vals_GA, ts_vals_GA)
    ff = h5open("./results/GA/3D-lorenz-multi/lorenz_multi_no"*string(i)*".h5", "w")
    ff["Embedding"] = Matrix(Recon_GA)
    ff["delays"] = τ_vals_GA
    ff["variables"] = ts_vals_GA
    close(ff)
    close(fid)
end


for i = 1:100
    # fid = h5open("./data/3D-lorenz/lorenz_no"*string(i)*".h5", "r")
    fid = h5open("./data/Rossler/rossler_no"*string(i)*".h5", "r")
    # fid = h5open("./data/Lorenz96/lorenz96_N8_no"*string(i)*".h5", "r")
    Y = Array(fid["xM"])

    inds = [1,2] # input timeseries = x-component and y-component of Rossler
    theiler1 = estimate_delay(Y[:,inds[1]], "mi_min") # estimate a Theiler window
    theiler2 = estimate_delay(Y[:,inds[2]], "mi_min")
    w = maximum(hcat(theiler1, theiler2))
    Tmax = 50 # maximum possible delay


    Recon_GA, τ_vals_GA, ts_vals_GA, FNNs_GA , ns_GA = garcia_almeida_embedding(Dataset(Y[:,inds]); τs = 0:Tmax , w = w, T = w)
    println(τ_vals_GA, ts_vals_GA)
    ff = h5open("./results/GA/Rossler-multi/rossler_multi_no"*string(i)*".h5", "w")
    ff["Embedding"] = Matrix(Recon_GA)
    ff["delays"] = τ_vals_GA
    ff["variables"] = ts_vals_GA
    close(ff)
    close(fid)
end

for i = 1:100
    # fid = h5open("./data/3D-lorenz/lorenz_no"*string(i)*".h5", "r")
    # fid = h5open("./data/Rossler/rossler_no"*string(i)*".h5", "r")
    fid = h5open("./data/Lorenz96/lorenz96_N8_no"*string(i)*".h5", "r")
    Y = Array(fid["xM"])

    inds = [2,6] # input timeseries = x2-component and x6-component of Lorenz96
    theiler1 = estimate_delay(Y[:,inds[1]], "mi_min") # estimate a Theiler window
    theiler2 = estimate_delay(Y[:,inds[2]], "mi_min")
    w = maximum(hcat(theiler1, theiler2))
    Tmax = 50 # maximum possible delay


    Recon_GA, τ_vals_GA, ts_vals_GA, FNNs_GA , ns_GA = garcia_almeida_embedding(Dataset(Y[:,inds]); τs = 0:Tmax , w = w, T = w)
    println(τ_vals_GA, ts_vals_GA)
    ff = h5open("./results/GA/Lorenz96-multi/lorenz96_multi_no"*string(i)*".h5", "w")
    ff["Embedding"] = Matrix(Recon_GA)
    ff["delays"] = τ_vals_GA
    ff["variables"] = ts_vals_GA
    close(ff)
    close(fid)
end
